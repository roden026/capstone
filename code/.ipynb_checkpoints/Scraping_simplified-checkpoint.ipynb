# %%
# Imports

import re #Regular expressions
from bs4 import BeautifulSoup # a python HTML parser
import requests
import string
import pandas as pd

# %%
'''
get_airlines(): Function to loop through the alphabet and return a list of all airline references. 
The function is pretty rigid to start. May revist to add some additional flexibility
'''

def get_airlines():
    
    # set url to airline reviews a-z review page
    url = "http://www.airlinequality.com/review-pages/a-z-airline-reviews/"
    
    # request the url
    r = requests.get(url)
    
    hrefs = []
    airlines = []
    
    # 200 status code indicates success
    if(r.status_code == 200):
        
        # Now use beautiful soup to pull in data (make soup)
        soup = BeautifulSoup(r.content, 'html.parser')
        
        # loop through all uppercase letters (A-Y, no Z airline reviews hence the try)
        for letter in list(string.ascii_uppercase[:26]):
            try:
                # add letter to id name determined above
                id_letter = "a2z-ldr-" + letter
                col_groups = soup.find(id=id_letter)

                # loop through all a elements to find the href data
                for a in col_groups.find_all('a', href=True):
                    hrefs.append(a['href'])
                    airlines.append(a.get_text())
                
    return hrefs, airlines

# %%
'''
get_data(airlines): function that takes in airlines (a list formatted like the get_airlines function return value, meaning [0] is href list 
and [1] is plain text name list) and returns the below data for all reviews on the given airlines. Data returned is a data frame with column
headers matching the data names below

'airline_name' - i.e. Delta Airlines
'link' - href showing airline-reviews/airline-name
'title' - title of the review
'author' - author name
'author_country' - author country
'date_published' - date review published
'date' - date of flight
'content' - review text
'aircraft' - type of aircraft flown
'type_traveller' - type of traveler (i.e. business, leisure, etc)
'cabin_flown' - cabin flown during trip
'route' - route flown
'overall_rating' - 1- 10 rating for the experience
'seat_comfort_rating' - 1- 5 rating
'cabin_staff_rating' - 1- 5 rating
'food_beverages_rating' - 1 - 5 rating
'inflight_entertainment_rating' - 1 - 5 rating
'ground_service_rating' - 1 - 5 rating
'wifi_connectivity_rating' - 1 - 5 rating
'value_money_rating' - 1 - 5 rating
'recommended' - 1 if yes, would recommend, 0 if no, would not recommend
'''

def get_data(airlines):
    
    # URL structure of a reviews page
    # http://www.airlinequality.com/airline-reviews/ba-cityflyer/page/1/
    url_start = "http://www.airlinequality.com"
    url_end = "/page/"
    
    # make a list of the urls (with out the page numbers)
    urls = [url_start + link + url_end for link in airlines[0]]
    
    # store list of names for easier referencing
    names = airlines[1]
    
    # data - list of dictionaries where each dictionary will be a record
    out_data = []
    
    # for each airline
    for i in list(range(len(urls))):
        
        # print current airline url to monitor status - will only show once per airline, not once per page
        print(urls[i])
        
        # set flag and counter for conditional loop because number of pages per airline is unknown
        valid_page = True
        page_num = 1
        # x = 1 # counter used to track total reviews per airline during debug or to show status
        
        # while a page is still showing reviews (reviews > 0 and reviews is not None)
        while valid_page:
            
            # form new url, if none type returned on request, end loop, else get content 
            url_page = str(urls[i] +str(page_num) + "/")
            
            # request the page and "make soup!"
            r = requests.get(url_page)
            soup = BeautifulSoup(r.content, 'html.parser')
            
            # find all reviews on the page
            reviews = soup.find_all(itemprop="review")

            # if no reviews are found then we have exceeded the page limit
            if len(reviews) > 0 and reviews is not None:
            
                # loop through reviews
                for review in reviews:
                    
                    # dictionary to store data - this will be appended to a larger list/(eventual)dataframe which will have values from all reviews
                    record = {"airline": names[i], 'link': urls[i]}

                    # find specifically the content section of the review
                    content = review.find(itemprop="reviewBody").get_text()
                    content = content[(content.find('| ')+3):] #formatting
                    
                    # overall_rating section of the review
                    overall = review.find(itemprop="ratingValue").get_text()

                    # title
                    title = review.find('h2', {'class': 'text_header'}).get_text()
                    
                    # author, author country, and date_published
                    author, author_country, date_published = review.find('h3', {'class': "text_sub_header userStatusWrapper"}).get_text().strip().replace('(', ')').split(sep=')') # ~PyThOnIc~
                    
                    # add key value pairs to records                    
                    record.update({'author': author, 'author_country': author_country, 'date_published': date_published, 'title': title, "overall_rating": overall, "content": content})
                    
                    # now look for data in review rating table
                    table = review.find('table', attrs={'class':'review-ratings'})
                    
                    # grab all records in the review rating table and loop through the rows
                    if table is not None: # theoretically this shouldn't happen but one page was throwing an error here due to a NoneType
                        for item in table.findAll('tr'):
                            # table structure on reviews has 2 td values for every tr, the first td is the field and the second td is the value
                            pair = item.findAll('td')
                            
                            # some items in this table are as 1-5 star ratings, if that's the case an extra step is needed
                            if item.find('td', {'class': 'review-rating-stars stars'}) is None:
                                record.update({pair[0].get_text():pair[1].get_text()})

                            else:
                                record.update({pair[0].get_text(): len(pair[1].find_all('span', {'class': 'star fill'}))})

                        # add this record to the larger data set
                        out_data.append(record)

                    # print('review {}'.format(x))
                    # x += 1
                # increment the page number because all reviews on the page have been read
                page_num += 1
            
            # len reviews 0 or reviews is NoneType, then move to next airline
            else:
                valid_page = False
    
    # convert dictionaries to data frame
    out_data_df = pd.DataFrame(out_data)
    
    # rename dataframe to align to original dataset names and to generally be more nicely formatted
    out_data_df = out_data_df.rename(columns={'Aircraft': 'aircraft', 'Cabin Flown': 'cabin_flown', 'Cabin Staff Service':'cabin_staff_rating', 'Date Flown':'date',
       'Food & Beverages': 'food_beverages_rating', 'Ground Service': 'ground_service_rating', 'Inflight Entertainment': 'inflight_entertainment_rating',
       'Recommended': 'recommended', 'Route': 'route', 'Seat Comfort': 'seat_comfort_rating', 'Type Of Traveller': 'type_traveller',
       'Value For Money': 'value_money_rating', 'Wifi & Connectivity': 'wifi_connectivity_rating', 'airline': 'airline_name', 'content': 'content', 'link': 'link'})
    
    # Convert recommended to numbers
    out_data_df['recommended'] = [1 if r == 'yes' else 0 for r in out_data_df.recommended]
    
    print('Done! - Here is your data')
        
    return out_data_df

# %%
from time import gmtime, strftime
print('start time: ' + strftime("%Y-%m-%d %H:%M:%S", gmtime()))

airlines = get_airlines()
'''
# single airline sample
href = ["/airline-reviews/sata-air-azores"]
airline = ["SATA Air Azores"]

airlines = []
airlines.append(href)
airlines.append(airline)
print(airlines)
'''
results = get_data(airlines)

print('end time: ' + strftime("%Y-%m-%d %H:%M:%S", gmtime()))
# Out:
# 2018-07-26 14:58:20
# http://www.airlinequality.com/airline-reviews/adria-airways/page/
# http://www.airlinequality.com/airline-reviews/aegean-airlines/page/
# http://www.airlinequality.com/airline-reviews/aer-lingus/page/
# http://www.airlinequality.com/airline-reviews/aero-vip/page/
# http://www.airlinequality.com/airline-reviews/aerocaribbean/page/
# http://www.airlinequality.com/airline-reviews/aeroflot-russian-airlines/page/
# http://www.airlinequality.com/airline-reviews/aerolineas-argentinas/page/
# http://www.airlinequality.com/airline-reviews/aeromar/page/
# http://www.airlinequality.com/airline-reviews/aeromexico/page/
# http://www.airlinequality.com/airline-reviews/aerosur/page/
# http://www.airlinequality.com/airline-reviews/africa-world-airlines/page/
# http://www.airlinequality.com/airline-reviews/afriqiyah-airways/page/
# http://www.airlinequality.com/airline-reviews/aigle-azur/page/
# http://www.airlinequality.com/airline-reviews/air-algerie/page/
# http://www.airlinequality.com/airline-reviews/air-arabia/page/
# http://www.airlinequality.com/airline-reviews/air-astana/page/
# http://www.airlinequality.com/airline-reviews/air-austral/page/
# http://www.airlinequality.com/airline-reviews/air-bagan/page/
# http://www.airlinequality.com/airline-reviews/air-berlin/page/
# http://www.airlinequality.com/airline-reviews/air-botswana/page/
# http://www.airlinequality.com/airline-reviews/air-busan/page/
# http://www.airlinequality.com/airline-reviews/air-cairo/page/
# http://www.airlinequality.com/airline-reviews/air-canada/page/
# http://www.airlinequality.com/airline-reviews/air-canada-rouge/page/
# http://www.airlinequality.com/airline-reviews/air-caraibes/page/
# http://www.airlinequality.com/airline-reviews/air-china/page/
# http://www.airlinequality.com/airline-reviews/air-corsica/page/
# http://www.airlinequality.com/airline-reviews/air-costa/page/
# http://www.airlinequality.com/airline-reviews/air-dolomiti/page/
# http://www.airlinequality.com/airline-reviews/air-europa/page/
# http://www.airlinequality.com/airline-reviews/air-france/page/
# http://www.airlinequality.com/airline-reviews/air-greenland/page/
# http://www.airlinequality.com/airline-reviews/air-iceland-connect/page/
# http://www.airlinequality.com/airline-reviews/air-india/page/
# http://www.airlinequality.com/airline-reviews/air-india-express/page/
# http://www.airlinequality.com/airline-reviews/air-italy/page/
# http://www.airlinequality.com/airline-reviews/air-juan/page/
# http://www.airlinequality.com/airline-reviews/air-kbz/page/
# http://www.airlinequality.com/airline-reviews/air-koryo/page/
# http://www.airlinequality.com/airline-reviews/air-labrador/page/
# http://www.airlinequality.com/airline-reviews/air-macau/page/
# http://www.airlinequality.com/airline-reviews/air-madagascar/page/
# http://www.airlinequality.com/airline-reviews/air-malawi/page/
# http://www.airlinequality.com/airline-reviews/air-malta/page/
# http://www.airlinequality.com/airline-reviews/air-mauritius/page/
# http://www.airlinequality.com/airline-reviews/air-mediterranee/page/
# http://www.airlinequality.com/airline-reviews/air-memphis/page/
# http://www.airlinequality.com/airline-reviews/air-moldova/page/
# http://www.airlinequality.com/airline-reviews/air-namibia/page/
# http://www.airlinequality.com/airline-reviews/air-new-zealand/page/
# http://www.airlinequality.com/airline-reviews/air-niugini/page/
# http://www.airlinequality.com/airline-reviews/air-north-yukons-airline/page/
# http://www.airlinequality.com/airline-reviews/air-nostrum/page/
# http://www.airlinequality.com/airline-reviews/air-panama/page/
# http://www.airlinequality.com/airline-reviews/air-pegasus/page/
# http://www.airlinequality.com/airline-reviews/air-serbia/page/
# http://www.airlinequality.com/airline-reviews/air-seychelles/page/
# http://www.airlinequality.com/airline-reviews/air-tahiti-nui/page/
# http://www.airlinequality.com/airline-reviews/air-transat/page/
# http://www.airlinequality.com/airline-reviews/air-vanuata/page/
# http://www.airlinequality.com/airline-reviews/air-zimbabwe/page/
# http://www.airlinequality.com/airline-reviews/airasia/page/
# http://www.airlinequality.com/airline-reviews/airasia-india/page/
# http://www.airlinequality.com/airline-reviews/airasia-philippines/page/
# http://www.airlinequality.com/airline-reviews/airasia-x/page/
# http://www.airlinequality.com/airline-reviews/airasia-zest/page/
# http://www.airlinequality.com/airline-reviews/airbaltic/page/
# http://www.airlinequality.com/airline-reviews/air-blue/page/
# http://www.airlinequality.com/airline-reviews/aircalin/page/
# http://www.airlinequality.com/airline-reviews/airlink/page/
# http://www.airlinequality.com/airline-reviews/airnorth/page/
# http://www.airlinequality.com/airline-reviews/airswift/page/
# http://www.airlinequality.com/airline-reviews/alaska-airlines/page/
# http://www.airlinequality.com/airline-reviews/alitalia/page/
# http://www.airlinequality.com/airline-reviews/allegiant-air/page/
# http://www.airlinequality.com/airline-reviews/alliance-airlines/page/
# http://www.airlinequality.com/airline-reviews/amaszonas/page/
# http://www.airlinequality.com/airline-reviews/american-airlines/page/
# http://www.airlinequality.com/airline-reviews/american-eagle/page/
# http://www.airlinequality.com/airline-reviews/ana-all-nippon-airways/page/
# http://www.airlinequality.com/airline-reviews/anadolujet/page/
# http://www.airlinequality.com/airline-reviews/ariana-afghan-airlines/page/
# http://www.airlinequality.com/airline-reviews/arik-air/page/
# http://www.airlinequality.com/airline-reviews/arkefly/page/
# http://www.airlinequality.com/airline-reviews/arkia-israeli/page/
# http://www.airlinequality.com/airline-reviews/asiana-airlines/page/
# http://www.airlinequality.com/airline-reviews/asky-airlines/page/
# http://www.airlinequality.com/airline-reviews/ata-airlines/page/
# http://www.airlinequality.com/airline-reviews/atlantic-airways/page/
# http://www.airlinequality.com/airline-reviews/atlasjet-airlines/page/
# http://www.airlinequality.com/airline-reviews/aurigny-air/page/
# http://www.airlinequality.com/airline-reviews/austrian-airlines/page/
# http://www.airlinequality.com/airline-reviews/avianca/page/
# http://www.airlinequality.com/airline-reviews/avianca-brasil/page/
# http://www.airlinequality.com/airline-reviews/aerogal-aerolineas-galapagos/page/
# http://www.airlinequality.com/airline-reviews/avior-airlines/page/
# http://www.airlinequality.com/airline-reviews/azerbaijan-airlines/page/
# http://www.airlinequality.com/airline-reviews/azul-linhas-aereas-brasileiras/page/
# http://www.airlinequality.com/airline-reviews/azur-air-germany/page/
# http://www.airlinequality.com/airline-reviews/ba-cityflyer/page/
# http://www.airlinequality.com/airline-reviews/badr-airlines/page/
# http://www.airlinequality.com/airline-reviews/bahamasair/page/
# http://www.airlinequality.com/airline-reviews/bangkok-airways/page/
# http://www.airlinequality.com/airline-reviews/bassaka-air/page/
# http://www.airlinequality.com/airline-reviews/batik-air/page/
# http://www.airlinequality.com/airline-reviews/beijing-capital-airlines/page/
# http://www.airlinequality.com/airline-reviews/belavia/page/
# http://www.airlinequality.com/airline-reviews/berjaya-air/page/
# http://www.airlinequality.com/airline-reviews/bh-airlines/page/
# http://www.airlinequality.com/airline-reviews/bhutan-airlines/page/
# http://www.airlinequality.com/airline-reviews/biman-bangladesh/page/
# http://www.airlinequality.com/airline-reviews/binter-canarias/page/
# http://www.airlinequality.com/airline-reviews/bluexpress/page/
# http://www.airlinequality.com/airline-reviews/blue-air/page/
# http://www.airlinequality.com/airline-reviews/blue-islands/page/
# http://www.airlinequality.com/airline-reviews/blue-panorama-airlines/page/
# http://www.airlinequality.com/airline-reviews/blue1/page/
# http://www.airlinequality.com/airline-reviews/bmi-regional/page/
# http://www.airlinequality.com/airline-reviews/boliviana-de-aviacin/page/
# http://www.airlinequality.com/airline-reviews/borajet/page/
# http://www.airlinequality.com/airline-reviews/boutique-air/page/
# http://www.airlinequality.com/airline-reviews/british-airways/page/
# http://www.airlinequality.com/airline-reviews/brussels-airlines/page/
# http://www.airlinequality.com/airline-reviews/buddha-air/page/
# http://www.airlinequality.com/airline-reviews/bulgaria-air/page/
# http://www.airlinequality.com/airline-reviews/buraq/page/
# http://www.airlinequality.com/airline-reviews/camair-co/page/
# http://www.airlinequality.com/airline-reviews/cambodia-angkor-airlines/page/
# http://www.airlinequality.com/airline-reviews/cambodia-bayon-airlines/page/
# http://www.airlinequality.com/airline-reviews/canadian-north/page/
# http://www.airlinequality.com/airline-reviews/canaryfly/page/
# http://www.airlinequality.com/airline-reviews/cape-air/page/
# http://www.airlinequality.com/airline-reviews/caribbean-airlines/page/
# http://www.airlinequality.com/airline-reviews/carpatair/page/
# http://www.airlinequality.com/airline-reviews/cathay-dragon/page/
# http://www.airlinequality.com/airline-reviews/cathay-pacific-airways/page/
# http://www.airlinequality.com/airline-reviews/cayman-airways/page/
# http://www.airlinequality.com/airline-reviews/cebu-pacific/page/
# http://www.airlinequality.com/airline-reviews/central-mountain-air/page/
# http://www.airlinequality.com/airline-reviews/china-airlines/page/
# http://www.airlinequality.com/airline-reviews/china-eastern-airlines/page/
# http://www.airlinequality.com/airline-reviews/china-southern-airlines/page/
# http://www.airlinequality.com/airline-reviews/china-united-airlines/page/
# http://www.airlinequality.com/airline-reviews/citilink/page/
# http://www.airlinequality.com/airline-reviews/cityjet/page/
# http://www.airlinequality.com/airline-reviews/coastal-aviation/page/
# http://www.airlinequality.com/airline-reviews/cobalt/page/
# http://www.airlinequality.com/airline-reviews/comair/page/
# http://www.airlinequality.com/airline-reviews/condor-airlines/page/
# http://www.airlinequality.com/airline-reviews/conviasa/page/
# http://www.airlinequality.com/airline-reviews/copa-airlines/page/
# http://www.airlinequality.com/airline-reviews/corendon-airlines/page/
# http://www.airlinequality.com/airline-reviews/corsair/page/
# http://www.airlinequality.com/airline-reviews/croatia-airlines/page/
# http://www.airlinequality.com/airline-reviews/csa-czech-airlines/page/
# http://www.airlinequality.com/airline-reviews/cubana-airlines/page/
# http://www.airlinequality.com/airline-reviews/danish-air/page/
# http://www.airlinequality.com/airline-reviews/darwin/page/
# http://www.airlinequality.com/airline-reviews/delta-air-lines/page/
# http://www.airlinequality.com/airline-reviews/dniproavia/page/
# http://www.airlinequality.com/airline-reviews/dragonair/page/
# http://www.airlinequality.com/airline-reviews/druk-air/page/
# http://www.airlinequality.com/airline-reviews/dynamic-international-airways/page/
# http://www.airlinequality.com/airline-reviews/eastarjet/page/
# http://www.airlinequality.com/airline-reviews/eastern-airways/page/
# http://www.airlinequality.com/airline-reviews/easyfly/page/
# http://www.airlinequality.com/airline-reviews/easyjet/page/
# http://www.airlinequality.com/airline-reviews/edelweiss-air/page/
# http://www.airlinequality.com/airline-reviews/egyptair/page/
# http://www.airlinequality.com/airline-reviews/el-al-israel-airlines/page/
# http://www.airlinequality.com/airline-reviews/ellinair/page/
# http://www.airlinequality.com/airline-reviews/emirates/page/
# http://www.airlinequality.com/airline-reviews/eritrean-airlines/page/
# http://www.airlinequality.com/airline-reviews/estonian-air/page/
# http://www.airlinequality.com/airline-reviews/ethiopian-airlines/page/
# http://www.airlinequality.com/airline-reviews/etihad-airways/page/
# http://www.airlinequality.com/airline-reviews/euroatlantic-airways/page/
# http://www.airlinequality.com/airline-reviews/europe-airpost/page/
# http://www.airlinequality.com/airline-reviews/eurowings/page/
# http://www.airlinequality.com/airline-reviews/eva-air/page/
# http://www.airlinequality.com/airline-reviews/evelop-airlines/page/
# http://www.airlinequality.com/airline-reviews/far-eastern/page/
# http://www.airlinequality.com/airline-reviews/fastjet/page/
# http://www.airlinequality.com/airline-reviews/felix-airways/page/
# http://www.airlinequality.com/airline-reviews/fiji-airways/page/
# http://www.airlinequality.com/airline-reviews/finnair/page/
# http://www.airlinequality.com/airline-reviews/firefly/page/
# http://www.airlinequality.com/airline-reviews/flair-airlines/page/
# http://www.airlinequality.com/airline-reviews/fly540-com/page/
# http://www.airlinequality.com/airline-reviews/flyadeal/page/
# http://www.airlinequality.com/airline-reviews/flybe/page/
# http://www.airlinequality.com/airline-reviews/flydubai/page/
# http://www.airlinequality.com/airline-reviews/flynas/page/
# http://www.airlinequality.com/airline-reviews/flysafair/page/
# http://www.airlinequality.com/airline-reviews/fmi-air/page/
# http://www.airlinequality.com/airline-reviews/free-bird/page/
# http://www.airlinequality.com/airline-reviews/french-bee/page/
# http://www.airlinequality.com/airline-reviews/frontier-airlines/page/
# http://www.airlinequality.com/airline-reviews/garuda-indonesia/page/
# http://www.airlinequality.com/airline-reviews/georgian-airways/page/
# http://www.airlinequality.com/airline-reviews/germania-airline/page/
# http://www.airlinequality.com/airline-reviews/germanwings/page/
# http://www.airlinequality.com/airline-reviews/goair/page/
# http://www.airlinequality.com/airline-reviews/gol/page/
# http://www.airlinequality.com/airline-reviews/golden-myanmar-airlines/page/
# http://www.airlinequality.com/airline-reviews/grand-cru-airlines/page/
# http://www.airlinequality.com/airline-reviews/gulf-air/page/
# http://www.airlinequality.com/airline-reviews/hainan-airlines/page/
# http://www.airlinequality.com/airline-reviews/hawaiian-airlines/page/
# http://www.airlinequality.com/airline-reviews/helvetic/page/
# http://www.airlinequality.com/airline-reviews/henan-airlines/page/
# http://www.airlinequality.com/airline-reviews/hi-fly/page/
# http://www.airlinequality.com/airline-reviews/hong-kong/page/
# http://www.airlinequality.com/airline-reviews/hong-kong-airlines/page/
# http://www.airlinequality.com/airline-reviews/hop/page/
# http://www.airlinequality.com/airline-reviews/horizon-air/page/
# http://www.airlinequality.com/airline-reviews/iberia/page/
# http://www.airlinequality.com/airline-reviews/iberia-express/page/
# http://www.airlinequality.com/airline-reviews/icelandair/page/
# http://www.airlinequality.com/airline-reviews/indigo-airlines/page/
# http://www.airlinequality.com/airline-reviews/insel-air/page/
# http://www.airlinequality.com/airline-reviews/interjet/page/
# http://www.airlinequality.com/airline-reviews/intersky/page/
# http://www.airlinequality.com/airline-reviews/iran-air/page/
# http://www.airlinequality.com/airline-reviews/iran-aseman/page/
# http://www.airlinequality.com/airline-reviews/iraqi-airways/page/
# http://www.airlinequality.com/airline-reviews/island/page/
# http://www.airlinequality.com/airline-reviews/israir-airlines/page/
# http://www.airlinequality.com/airline-reviews/japan-airlines/page/
# http://www.airlinequality.com/airline-reviews/jazeera-airways/page/
# http://www.airlinequality.com/airline-reviews/jazz/page/
# http://www.airlinequality.com/airline-reviews/jeju-air/page/
# http://www.airlinequality.com/airline-reviews/jet-airways/page/
# http://www.airlinequality.com/airline-reviews/jet2-com/page/
# http://www.airlinequality.com/airline-reviews/jetairfly/page/
# http://www.airlinequality.com/airline-reviews/jetblue-airways/page/
# http://www.airlinequality.com/airline-reviews/jetstar-airways/page/
# http://www.airlinequality.com/airline-reviews/jetstar-asia/page/
# http://www.airlinequality.com/airline-reviews/jetstar-japan/page/
# http://www.airlinequality.com/airline-reviews/jetstar-pacific/page/
# http://www.airlinequality.com/airline-reviews/jin-air/page/
# http://www.airlinequality.com/airline-reviews/joon/page/
# http://www.airlinequality.com/airline-reviews/juneyao-airlines/page/
# http://www.airlinequality.com/airline-reviews/kam-air/page/
# http://www.airlinequality.com/airline-reviews/kan-air/page/
# http://www.airlinequality.com/airline-reviews/karthago-airlines/page/
# http://www.airlinequality.com/airline-reviews/kenya-airways/page/
# http://www.airlinequality.com/airline-reviews/kish-air/page/
# http://www.airlinequality.com/airline-reviews/klm-royal-dutch-airlines/page/
# http://www.airlinequality.com/airline-reviews/korean-air/page/
# http://www.airlinequality.com/airline-reviews/kulula/page/
# http://www.airlinequality.com/airline-reviews/kuwait-airways/page/
# http://www.airlinequality.com/airline-reviews/la-compagnie/page/
# http://www.airlinequality.com/airline-reviews/lam-mozambique-airlines/page/
# http://www.airlinequality.com/airline-reviews/lan-airlines/page/
# http://www.airlinequality.com/airline-reviews/lan-colombia/page/
# http://www.airlinequality.com/airline-reviews/lan-peru/page/
# http://www.airlinequality.com/airline-reviews/lao-airlines/page/
# http://www.airlinequality.com/airline-reviews/latam-airlines/page/
# http://www.airlinequality.com/airline-reviews/lc-peru/page/
# http://www.airlinequality.com/airline-reviews/level/page/
# http://www.airlinequality.com/airline-reviews/liat/page/
# http://www.airlinequality.com/airline-reviews/libyan-airlines/page/
# http://www.airlinequality.com/airline-reviews/lion-air/page/
# http://www.airlinequality.com/airline-reviews/loch-lomond-seaplanes/page/
# http://www.airlinequality.com/airline-reviews/loganair/page/
# http://www.airlinequality.com/airline-reviews/lot-polish-airlines/page/
# http://www.airlinequality.com/airline-reviews/lucky-air/page/
# http://www.airlinequality.com/airline-reviews/lufthansa/page/
# http://www.airlinequality.com/airline-reviews/luxair/page/
# http://www.airlinequality.com/airline-reviews/madagasikara-airways/page/
# http://www.airlinequality.com/airline-reviews/mahan-air/page/
# http://www.airlinequality.com/airline-reviews/malawian-airlines/page/
# http://www.airlinequality.com/airline-reviews/malaysia-airlines/page/
# http://www.airlinequality.com/airline-reviews/maldivian/page/
# http://www.airlinequality.com/airline-reviews/malindo-air/page/
# http://www.airlinequality.com/airline-reviews/malm-aviation/page/
# http://www.airlinequality.com/airline-reviews/mandarin-airlines/page/
# http://www.airlinequality.com/airline-reviews/mango/page/
# http://www.airlinequality.com/airline-reviews/mann-yadanarpon-airlines/page/
# http://www.airlinequality.com/airline-reviews/martinair/page/
# http://www.airlinequality.com/airline-reviews/mayair/page/
# http://www.airlinequality.com/airline-reviews/mega-maldives-airlines/page/
# http://www.airlinequality.com/airline-reviews/meridiana/page/
# http://www.airlinequality.com/airline-reviews/miat-mongolian/page/
# http://www.airlinequality.com/airline-reviews/mea-middle-east-airlines/page/
# http://www.airlinequality.com/airline-reviews/mihin-lanka/page/
# http://www.airlinequality.com/airline-reviews/mokulele-airlines/page/
# http://www.airlinequality.com/airline-reviews/moldavian-airlines/page/
# http://www.airlinequality.com/airline-reviews/monarch-airlines/page/
# http://www.airlinequality.com/airline-reviews/montenegro-airlines/page/
# http://www.airlinequality.com/airline-reviews/myanmar-airways/page/
# http://www.airlinequality.com/airline-reviews/myanmar-national-airlines/page/
# http://www.airlinequality.com/airline-reviews/nam-air/page/
# http://www.airlinequality.com/airline-reviews/nature-air/page/
# http://www.airlinequality.com/airline-reviews/nepal-airlines/page/
# http://www.airlinequality.com/airline-reviews/nextjet/page/
# http://www.airlinequality.com/airline-reviews/niki/page/
# http://www.airlinequality.com/airline-reviews/nok-air/page/
# http://www.airlinequality.com/airline-reviews/nordavia/page/
# http://www.airlinequality.com/airline-reviews/nordica/page/
# http://www.airlinequality.com/airline-reviews/norwegian/page/
# http://www.airlinequality.com/airline-reviews/nouvelair/page/
# http://www.airlinequality.com/airline-reviews/novair/page/
# http://www.airlinequality.com/airline-reviews/okay-airways/page/
# http://www.airlinequality.com/airline-reviews/olympic-air/page/
# http://www.airlinequality.com/airline-reviews/oman-air/page/
# http://www.airlinequality.com/airline-reviews/omni-air-international/page/
# http://www.airlinequality.com/airline-reviews/onur-air/page/
# http://www.airlinequality.com/airline-reviews/openskies/page/
# http://www.airlinequality.com/airline-reviews/orient-thai/page/
# http://www.airlinequality.com/airline-reviews/pia-pakistan-international-airlines/page/
# http://www.airlinequality.com/airline-reviews/pal-express/page/
# http://www.airlinequality.com/airline-reviews/passaredo-linhas-aereas/page/
# http://www.airlinequality.com/airline-reviews/pawa-dominicana/page/
# http://www.airlinequality.com/airline-reviews/peach-aviation/page/
# http://www.airlinequality.com/airline-reviews/pegasus-airlines/page/
# http://www.airlinequality.com/airline-reviews/penair/page/
# http://www.airlinequality.com/airline-reviews/peruvian-airlines/page/
# http://www.airlinequality.com/airline-reviews/petroleum-air-services/page/
# http://www.airlinequality.com/airline-reviews/philippine-airlines/page/
# http://www.airlinequality.com/airline-reviews/phuket-air/page/
# http://www.airlinequality.com/airline-reviews/pobeda-airlines/page/
# http://www.airlinequality.com/airline-reviews/porter-airlines/page/
# http://www.airlinequality.com/airline-reviews/precision/page/
# http://www.airlinequality.com/airline-reviews/primera-air/page/
# http://www.airlinequality.com/airline-reviews/privilege-style/page/
# http://www.airlinequality.com/airline-reviews/qantas-airways/page/
# http://www.airlinequality.com/airline-reviews/qantaslink/page/
# http://www.airlinequality.com/airline-reviews/qatar-airways/page/
# http://www.airlinequality.com/airline-reviews/qazaq-air/page/
# http://www.airlinequality.com/airline-reviews/ravn-alaska/page/
# http://www.airlinequality.com/airline-reviews/regent-airways/page/
# http://www.airlinequality.com/airline-reviews/regional-express/page/
# http://www.airlinequality.com/airline-reviews/rossiya-airlines/page/
# http://www.airlinequality.com/airline-reviews/royal-air-maroc/page/
# http://www.airlinequality.com/airline-reviews/royal-brunei-airlines/page/
# http://www.airlinequality.com/airline-reviews/royal-jordanian-airlines/page/
# http://www.airlinequality.com/airline-reviews/rwandair/page/
# http://www.airlinequality.com/airline-reviews/ryanair/page/
# http://www.airlinequality.com/airline-reviews/s7-siberia-airlines/page/
# http://www.airlinequality.com/airline-reviews/sa-express/page/
# http://www.airlinequality.com/airline-reviews/safarilink/page/
# http://www.airlinequality.com/airline-reviews/safi-airways/page/
# http://www.airlinequality.com/airline-reviews/sansa-airlines/page/
# http://www.airlinequality.com/airline-reviews/santa-barbara/page/
# http://www.airlinequality.com/airline-reviews/sas-scandinavian-airlines/page/
# http://www.airlinequality.com/airline-reviews/sata-air-azores/page/
# http://www.airlinequality.com/airline-reviews/sata-internacional/page/
# http://www.airlinequality.com/airline-reviews/satena/page/
# http://www.airlinequality.com/airline-reviews/saudi-arabian-airlines/page/
# http://www.airlinequality.com/airline-reviews/scat-airlines/page/
# http://www.airlinequality.com/airline-reviews/scoot/page/
# http://www.airlinequality.com/airline-reviews/seaborne-airlines/page/
# http://www.airlinequality.com/airline-reviews/sereneair/page/
# http://www.airlinequality.com/airline-reviews/shaheen-air/page/
# http://www.airlinequality.com/airline-reviews/shandong-airlines/page/
# http://www.airlinequality.com/airline-reviews/shanghai-airlines/page/
# http://www.airlinequality.com/airline-reviews/shenzhen-airlines/page/
# http://www.airlinequality.com/airline-reviews/sichuan-airlines/page/
# http://www.airlinequality.com/airline-reviews/silkair/page/
# http://www.airlinequality.com/airline-reviews/silver-airways/page/
# http://www.airlinequality.com/airline-reviews/singapore-airlines/page/
# http://www.airlinequality.com/airline-reviews/sky-airline/page/
# http://www.airlinequality.com/airline-reviews/sky-express-airlines/page/
# http://www.airlinequality.com/airline-reviews/skybus/page/
# http://www.airlinequality.com/airline-reviews/skymark-airlines/page/
# http://www.airlinequality.com/airline-reviews/skytrans-airlines/page/
# http://www.airlinequality.com/airline-reviews/skywest-airlines/page/
# http://www.airlinequality.com/airline-reviews/skywork-airlines/page/
# http://www.airlinequality.com/airline-reviews/small-planet-airlines-uab/page/
# http://www.airlinequality.com/airline-reviews/smartwings/page/
# http://www.airlinequality.com/airline-reviews/sol-lineas-aereas/page/
# http://www.airlinequality.com/airline-reviews/solomon-airlines/page/
# http://www.airlinequality.com/airline-reviews/somon-air/page/
# http://www.airlinequality.com/airline-reviews/south-african-airways/page/
# http://www.airlinequality.com/airline-reviews/southwest-airlines/page/
# http://www.airlinequality.com/airline-reviews/spicejet/page/
# http://www.airlinequality.com/airline-reviews/spirit-airlines/page/
# http://www.airlinequality.com/airline-reviews/spring/page/
# http://www.airlinequality.com/airline-reviews/srilankan-airlines/page/
# http://www.airlinequality.com/airline-reviews/sriwijaya-air/page/
# http://www.airlinequality.com/airline-reviews/star-per/page/
# http://www.airlinequality.com/airline-reviews/starflyer/page/
# http://www.airlinequality.com/airline-reviews/sudan-airways/page/
# http://www.airlinequality.com/airline-reviews/sun-country-airlines/page/
# http://www.airlinequality.com/airline-reviews/sun-air/page/
# http://www.airlinequality.com/airline-reviews/sun-express/page/
# http://www.airlinequality.com/airline-reviews/sunwing-airlines/page/
# http://www.airlinequality.com/airline-reviews/suparna-airlines/page/
# http://www.airlinequality.com/airline-reviews/surinam-airways/page/
# http://www.airlinequality.com/airline-reviews/swiss-international-air-lines/page/
# http://www.airlinequality.com/airline-reviews/swoop/page/
# http://www.airlinequality.com/airline-reviews/syrianair/page/
# http://www.airlinequality.com/airline-reviews/tway-air/page/
# http://www.airlinequality.com/airline-reviews/taag-angola-airlines/page/
# http://www.airlinequality.com/airline-reviews/taca/page/
# http://www.airlinequality.com/airline-reviews/taca-regional/page/
# http://www.airlinequality.com/airline-reviews/tacv-cabo/page/
# http://www.airlinequality.com/airline-reviews/tag-airlines/page/
# http://www.airlinequality.com/airline-reviews/tailwind-airlines/page/
# http://www.airlinequality.com/airline-reviews/tajikistan-airlines/page/
# http://www.airlinequality.com/airline-reviews/tam-airlines/page/
# http://www.airlinequality.com/airline-reviews/tame/page/
# http://www.airlinequality.com/airline-reviews/tame-linea-aerea-del-ecuador/page/
# http://www.airlinequality.com/airline-reviews/tap-portugal/page/
# http://www.airlinequality.com/airline-reviews/tar-aerolineas/page/
# http://www.airlinequality.com/airline-reviews/tarom-romanian-airlines/page/
# http://www.airlinequality.com/airline-reviews/thai-airasia/page/
# http://www.airlinequality.com/airline-reviews/thai-airways/page/
# http://www.airlinequality.com/airline-reviews/thai-lion-air/page/
# http://www.airlinequality.com/airline-reviews/thai-smile-airways/page/
# http://www.airlinequality.com/airline-reviews/thomas-cook-airlines/page/
# http://www.airlinequality.com/airline-reviews/thomas-cook-belgium-airlines-customer/page/
# http://www.airlinequality.com/airline-reviews/thomas-cook-airlines-scandinavia/page/
# http://www.airlinequality.com/airline-reviews/thomson-airways/page/
# http://www.airlinequality.com/airline-reviews/tianjin-airlines/page/
# http://www.airlinequality.com/airline-reviews/tibet-airlines/page/
# http://www.airlinequality.com/airline-reviews/tigerair/page/
# http://www.airlinequality.com/airline-reviews/tigerair-australia/page/
# http://www.airlinequality.com/airline-reviews/tigerair-taiwan/page/
# http://www.airlinequality.com/airline-reviews/titan-airways/page/
# http://www.airlinequality.com/airline-reviews/transaero-airlines/page/
# http://www.airlinequality.com/airline-reviews/transasia-airways/page/
# http://www.airlinequality.com/airline-reviews/transavia/page/
# http://www.airlinequality.com/airline-reviews/tropic-air-belize/page/
# http://www.airlinequality.com/airline-reviews/tui-airways/page/
# http://www.airlinequality.com/airline-reviews/tuifly/page/
# http://www.airlinequality.com/airline-reviews/tuifly-nordic/page/
# http://www.airlinequality.com/airline-reviews/tunisair/page/
# http://www.airlinequality.com/airline-reviews/turkish-airlines/page/
# http://www.airlinequality.com/airline-reviews/turkmenistan-airlines/page/
# http://www.airlinequality.com/airline-reviews/ukraine-international-airlines/page/
# http://www.airlinequality.com/airline-reviews/united-airlines/page/
# http://www.airlinequality.com/airline-reviews/up-by-el-al/page/
# http://www.airlinequality.com/airline-reviews/ural-airlines/page/
# http://www.airlinequality.com/airline-reviews/us-airways/page/
# http://www.airlinequality.com/airline-reviews/us-bangla-airlines/page/
# http://www.airlinequality.com/airline-reviews/utair-aviation/page/
# http://www.airlinequality.com/airline-reviews/uzbekistan-airways/page/
# http://www.airlinequality.com/airline-reviews/v-air/page/
# http://www.airlinequality.com/airline-reviews/vanilla-air/page/
# http://www.airlinequality.com/airline-reviews/viaair/page/
# http://www.airlinequality.com/airline-reviews/vietjetair/page/
# http://www.airlinequality.com/airline-reviews/vietnam-airlines/page/
# http://www.airlinequality.com/airline-reviews/virgin-america/page/
# http://www.airlinequality.com/airline-reviews/virgin-atlantic-airways/page/
# http://www.airlinequality.com/airline-reviews/virgin-australia/page/
# http://www.airlinequality.com/airline-reviews/vistara/page/
# http://www.airlinequality.com/airline-reviews/vivaaerobus/page/
# http://www.airlinequality.com/airline-reviews/vivacolombia/page/
# http://www.airlinequality.com/airline-reviews/vlm-airlines/page/
# http://www.airlinequality.com/airline-reviews/volaris/page/
# http://www.airlinequality.com/airline-reviews/volotea/page/
# http://www.airlinequality.com/airline-reviews/vueling-airlines/page/
# http://www.airlinequality.com/airline-reviews/wamos-air/page/
# http://www.airlinequality.com/airline-reviews/westjet/page/
# http://www.airlinequality.com/airline-reviews/wideroe/page/
# http://www.airlinequality.com/airline-reviews/winair/page/
# http://www.airlinequality.com/airline-reviews/wings-air/page/
# http://www.airlinequality.com/airline-reviews/wizz-air/page/
# http://www.airlinequality.com/airline-reviews/wow-air/page/
# http://www.airlinequality.com/airline-reviews/xiamen-airlines/page/
# http://www.airlinequality.com/airline-reviews/xl-airways-france/page/
# http://www.airlinequality.com/airline-reviews/yakutia-airlines/page/
# http://www.airlinequality.com/airline-reviews/yangon-airways/page/
# http://www.airlinequality.com/airline-reviews/yemenia/page/
# http://www.airlinequality.com/airline-reviews/yeti-airlines/page/
# Done!
# 2018-07-26 16:58:35

# %%
results.columns
# Out:
# Index(['Aircraft', 'Cabin Flown', 'Cabin Staff Service', 'Date Flown',
#        'Food & Beverages', 'Ground Service', 'Inflight Entertainment',
#        'Recommended', 'Route', 'Seat Comfort', 'Type Of Traveller',
#        'Value For Money', 'Wifi & Connectivity', 'airline', 'content', 'link'],
#       dtype='object')

# %%
results.shape
# Out:
# (79782, 16)

# %%
# Set up file read/folder structure
import os
os.chdir("C:\\Users\\erroden\\Desktop\\ML_Guild\\mlg_02_us\\Capstone")
results.to_csv("data\\airline_2.csv")
